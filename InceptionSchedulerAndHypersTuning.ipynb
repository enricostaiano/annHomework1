# %%
import tensorflow as tf
import numpy as np
from numpy import asarray
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix

from keras.callbacks import LearningRateScheduler

from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
import datetime 
import pathlib

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.6.4

# %%
seed = 42127
random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# ### Suppress warnings

# %%
import warnings
import logging

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)
tf.get_logger().setLevel('INFO')
tf.autograph.set_verbosity(0)

tf.get_logger().setLevel(logging.ERROR)
tf.get_logger().setLevel('ERROR')
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %% [markdown]
# # **DATASET**
#
#
# RGB images of 96x96 pixels.

# %%
def genAugmLayer(seed): 
    return tf.keras.Sequential([
     tfkl.RandomFlip("horizontal_and_vertical"),
     tfkl.RandomRotation(0.5),
     tfkl.RandomZoom( height_factor=(-0.3, 0.3), width_factor=(-0.3, 0.3),fill_mode = 'reflect',seed=seed) ])

# %% [markdown]
# ***SELECTIVE AUGMENTATION DONE TWO TIMES TO FEED THE NN MORE SAMPLES FROM CLASSES 1 AND 6 (~ 400 PER CLASS)***

# %%
imbalClasses = tf.keras.utils.image_dataset_from_directory( 
    '../input/selective-dataset/training_selective_data',
    labels='inferred',
    label_mode='categorical',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(96,96),
    subset = 'training',
    validation_split=0.15,
    seed=seed,
)

data_augmentation1 = genAugmLayer(17) 
dataAugmImbal = imbalClasses.map(lambda x , y : (data_augmentation1(x), y)) 
data_augmentation2 = genAugmLayer(271) 
dataAugmImbal = dataAugmImbal.concatenate(imbalClasses.map(lambda x , y : (data_augmentation2(x), y))) #double samples of classes 1 and 6
# Out:
# Found 414 files belonging to 8 classes.
# Using 352 files for training.

# %% [markdown]
# ***UNIVERSAL AUGMENTATION***

# %%
datapath = '../input/training-data-final/training_data_final'
training_set = tf.keras.utils.image_dataset_from_directory(
    datapath,
    labels='inferred',
    label_mode='categorical',
    class_names=None,
    color_mode='rgb',
    batch_size=32, 
    image_size=(96,96),
    shuffle=True,
    seed=seed,
    validation_split=0.15,
    subset='training'
)

validation_set = tf.keras.utils.image_dataset_from_directory(
    datapath,
    labels='inferred',
    label_mode='categorical',
    class_names=None,
    color_mode='rgb',
    batch_size=32, 
    image_size=(96,96),
    shuffle=True,
    seed=seed,
    validation_split=0.15,
    subset='validation'
)


labels = np.concatenate([y for x, y in training_set], axis=0) 
class_weights = class_weight.compute_class_weight(class_weight='balanced' ,classes = [i for i in range(8)] , y = np.argmax(labels, axis=-1) ) 
weights = dict(enumerate(class_weights)) 
print(weights)
# Out:
# Found 3542 files belonging to 8 classes.
# Using 3011 files for training.
# Found 3542 files belonging to 8 classes.
# Using 531 files for validation.
# {0: 2.3377329192546585, 1: 0.8217794759825328, 2: 0.8940023752969121, 3: 0.8515271493212669, 4: 0.8235776805251641, 5: 1.9914021164021165, 6: 0.8111530172413793, 7: 0.8982696897374701}

# %% [markdown]
# ***RESCALING***

# %%
data_augmentation = genAugmLayer(89)
training_set = training_set.concatenate(training_set.map(lambda x , y : (data_augmentation(x), y)) ) #total augm
training_set = training_set.concatenate(dataAugmImbal)
training_set = training_set.concatenate(imbalClasses)

# %%
AUTOTUNE = tf.data.AUTOTUNE
training_set = training_set.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
validation_set = validation_set.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # **Transfer Learning**

# %%
initial_time = datetime.datetime.now()
input_shape = (96, 96, 3)
epochs = 50 #to be defined

# %%
training_set = training_set.map(lambda x,y: (tf.keras.applications.inception_v3.preprocess_input(x), y))
validation_set = validation_set.map(lambda x,y: (tf.keras.applications.inception_v3.preprocess_input(x),y))

# %%
supernet = tf.keras.applications.inception_v3.InceptionV3( include_top=False, weights='imagenet')
supernet.trainable = True
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step

# %%
input_layer = tfkl.Input(input_shape)
x = tfkl.Resizing(height = 181, width = 181, interpolation = 'bicubic' )(input_layer)
x = supernet(x)
x = tfkl.GlobalAveragePooling2D()(x) 
x = tfkl.Dropout(rate=0.361)(x)
x = tfkl.Dense(units=224, name='Dense1', kernel_initializer=tfk.initializers.HeUniform(seed), kernel_regularizer = tf.keras.regularizers.L2(0.01),   activation='tanh')(x)
x = tfkl.Dropout(rate=0.326)(x)
output_layer = tfkl.Dense(units=8, activation='softmax', kernel_initializer=tfk.initializers.GlorotUniform(seed), name='output_layer')(x)
    
model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tf.keras.optimizers.Adam(), metrics='accuracy')

# %%
from datetime import datetime
def create_folders_and_callbacks(model_name):
    exps_dir = os.path.join('experiments')
    if not os.path.exists(exps_dir):
        os.makedirs(exps_dir)
    now = datetime.now().strftime('%b%d_%H-%M-%S')
    exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
    if not os.path.exists(exp_dir):
        os.makedirs(exp_dir)
    callbacks = []
    
    # Model checkpoint
      # ----------------
    ckpt_dir = os.path.join(exp_dir, 'ckpts')
    if not os.path.exists(ckpt_dir):
        os.makedirs(ckpt_dir)
          
    ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp.ckpt'), save_weights_only=True, save_best_only=True) #play here 
      
    callbacks.append(ckpt_callback)
    
    # Early Stopping
    # --------------
    es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True) #tuning point
    callbacks.append(es_callback)
    return callbacks

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 96, 96, 3)]       0
# _________________________________________________________________
# resizing (Resizing)          (None, 181, 181, 3)       0
# _________________________________________________________________
# inception_v3 (Functional)    (None, None, None, 2048)  21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# Dense1 (Dense)               (None, 224)               458976
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 224)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 8)                 1800
# =================================================================
# Total params: 22,263,560
# Trainable params: 22,229,128
# Non-trainable params: 34,432
# _________________________________________________________________

# %%
for i, layer in enumerate(model.get_layer('inception_v3').layers[:-1]):
    layer.trainable=False

for i, layer in enumerate(model.get_layer('inception_v3').layers[:30]):
    layer.trainable=True
    
for i, layer in enumerate(model.get_layer('inception_v3').layers[-40:-1]):
    layer.trainable = True

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 96, 96, 3)]       0
# _________________________________________________________________
# resizing (Resizing)          (None, 181, 181, 3)       0
# _________________________________________________________________
# inception_v3 (Functional)    (None, None, None, 2048)  21802784
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# Dense1 (Dense)               (None, 224)               458976
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 224)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 8)                 1800
# =================================================================
# Total params: 22,263,560
# Trainable params: 6,872,872
# Non-trainable params: 15,390,688
# _________________________________________________________________

# %%
# correction 
weights[7] = weights[7]*1.20 #weak class -> trying to compensate modifying the weight
weights[0] = weights[0]*1.30 #weak class -> trying to compensate modifying the weight

# %%
def exp_decay(epoch):
    lrate = learning_rate* np.exp(-decay_rate*epoch)
    return lrate
    
learning_rate=0.000324
decay_rate = learning_rate/epochs
lrate = LearningRateScheduler(exp_decay)

# %%
callbacks = create_folders_and_callbacks(model_name='myModel_TESTING')
callback_list = [callbacks, lrate]

history = model.fit(
    x = training_set,
    epochs = epochs,
    validation_data = validation_set, 
    callbacks = callback_list
    ,class_weight = weights 
).history
# Out:
# Epoch 1/50
# 223/223 [==============================] - 53s 130ms/step - loss: 5.5651 - accuracy: 0.4744 - val_loss: 4.8481 - val_accuracy: 0.4765
# Epoch 2/50
# 223/223 [==============================] - 25s 114ms/step - loss: 3.5184 - accuracy: 0.7180 - val_loss: 3.4091 - val_accuracy: 0.5518
# Epoch 3/50
# 223/223 [==============================] - 26s 114ms/step - loss: 2.0505 - accuracy: 0.8757 - val_loss: 2.4176 - val_accuracy: 0.6177
# Epoch 4/50
# 223/223 [==============================] - 25s 114ms/step - loss: 1.2489 - accuracy: 0.9302 - val_loss: 2.0657 - val_accuracy: 0.6610
# Epoch 5/50
# 223/223 [==============================] - 26s 116ms/step - loss: 0.7805 - accuracy: 0.9507 - val_loss: 4.1773 - val_accuracy: 0.2429
# Epoch 6/50
# 223/223 [==============================] - 26s 117ms/step - loss: 0.6960 - accuracy: 0.9138 - val_loss: 1.0947 - val_accuracy: 0.7928
# Epoch 7/50
# 223/223 [==============================] - 25s 113ms/step - loss: 0.4713 - accuracy: 0.9383 - val_loss: 1.0522 - val_accuracy: 0.7778
# Epoch 8/50
# 223/223 [==============================] - 26s 115ms/step - loss: 0.2550 - accuracy: 0.9764 - val_loss: 0.7100 - val_accuracy: 0.8324
# Epoch 9/50
# 223/223 [==============================] - 25s 114ms/step - loss: 0.1762 - accuracy: 0.9847 - val_loss: 0.5743 - val_accuracy: 0.8475
# Epoch 10/50
# 223/223 [==============================] - 25s 114ms/step - loss: 0.1010 - accuracy: 0.9959 - val_loss: 0.5813 - val_accuracy: 0.8569
# Epoch 11/50
# 223/223 [==============================] - 25s 114ms/step - loss: 0.0619 - accuracy: 0.9987 - val_loss: 0.4175 - val_accuracy: 0.8927
# Epoch 12/50
# 223/223 [==============================] - 25s 114ms/step - loss: 0.0451 - accuracy: 0.9982 - val_loss: 0.3991 - val_accuracy: 0.9002
# Epoch 13/50
# 223/223 [==============================] - 26s 115ms/step - loss: 0.0365 - accuracy: 0.9986 - val_loss: 0.4068 - val_accuracy: 0.8927
# Epoch 14/50
# 223/223 [==============================] - 25s 113ms/step - loss: 0.0257 - accuracy: 0.9999 - val_loss: 0.3731 - val_accuracy: 0.9058
# Epoch 15/50
# 223/223 [==============================] - 25s 114ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.3616 - val_accuracy: 0.9077
# Epoch 16/50
# 223/223 [==============================] - 25s 114ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.3350 - val_accuracy: 0.9096
# Epoch 17/50
# 223/223 [==============================] - 26s 114ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.4030 - val_accuracy: 0.8983
# Epoch 18/50
# 223/223 [==============================] - 25s 114ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.3898 - val_accuracy: 0.9040
# Epoch 19/50
# 223/223 [==============================] - 25s 114ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.3358 - val_accuracy: 0.9096
# Epoch 20/50
# 223/223 [==============================] - 25s 114ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.3439 - val_accuracy: 0.9058
# Epoch 21/50
# 223/223 [==============================] - 25s 114ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.3312 - val_accuracy: 0.9115
# Epoch 22/50
# 223/223 [==============================] - 26s 117ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.4187 - val_accuracy: 0.9040
# Epoch 23/50
# 223/223 [==============================] - 26s 115ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.3919 - val_accuracy: 0.8983
# Epoch 24/50
# 223/223 [==============================] - 26s 114ms/step - loss: 2.0372 - accuracy: 0.3925 - val_loss: 1.3632 - val_accuracy: 0.5593
# Epoch 25/50
# 223/223 [==============================] - 25s 114ms/step - loss: 1.7249 - accuracy: 0.4910 - val_loss: 2.1435 - val_accuracy: 0.2147
# Epoch 26/50
# 223/223 [==============================] - 26s 114ms/step - loss: 1.3145 - accuracy: 0.6318 - val_loss: 2.1840 - val_accuracy: 0.2674
# Epoch 27/50
# 223/223 [==============================] - 25s 114ms/step - loss: 1.0055 - accuracy: 0.7249 - val_loss: 2.2041 - val_accuracy: 0.3277
# Epoch 28/50
# 223/223 [==============================] - 25s 113ms/step - loss: 1.1649 - accuracy: 0.6694 - val_loss: 1.1221 - val_accuracy: 0.6215
# Epoch 29/50
# 223/223 [==============================] - 25s 114ms/step - loss: 0.8348 - accuracy: 0.7773 - val_loss: 1.0041 - val_accuracy: 0.7024
# Epoch 30/50
# 223/223 [==============================] - 26s 115ms/step - loss: 0.6118 - accuracy: 0.8420 - val_loss: 0.7765 - val_accuracy: 0.7778
# Epoch 31/50
# 223/223 [==============================] - 25s 114ms/step - loss: 0.4196 - accuracy: 0.9004 - val_loss: 1.0980 - val_accuracy: 0.6893

# %%
model.save("models/rew")

# %%
metrics = model.evaluate(validation_set, return_dict=True)
print(metrics)

DATASET_EVAL = validation_set
labels = np.concatenate([y for x, y in DATASET_EVAL], axis=0) 
predictions = model.predict(validation_set) 

assert len(labels) == len(predictions)

# Compute the confusion matrix
cm = confusion_matrix(np.argmax(labels, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(labels, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(labels, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(labels, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(labels, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1_classes = f1_score(np.argmax(labels, axis=-1), np.argmax(predictions, axis=-1), average=None)

print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))
print('F1 (per class):')
print(f1_classes)

print('WORST CLASS: Species:', np.argmin(f1_classes)+1)

# Plot the confusion matrix
ig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(cm, cmap=plt.cm.Blues, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')

        
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
# Out:
# 17/17 [==============================] - 1s 44ms/step - loss: 0.3312 - accuracy: 0.9115
# {'loss': 0.33118975162506104, 'accuracy': 0.9114877581596375}
# Accuracy: 0.9115
# Precision: 0.9003
# Recall: 0.91
# F1: 0.9039
# F1 (per class):
# [0.79245283 0.91275168 0.93478261 0.90909091 0.90322581 0.93939394
#  0.96551724 0.8742515 ]
# WORST CLASS: Species: 1
